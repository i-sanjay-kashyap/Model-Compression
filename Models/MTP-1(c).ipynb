# %%
import tensorflow as tf
import numpy as np
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# Load and preprocess the dataset
data = tf.keras.datasets.mnist
(training_images, training_labels), (test_images, test_labels) = data.load_data()

training_images = training_images / 255.0
test_images = test_images / 255.0

# Define the model
model = keras.Sequential([
    keras.layers.Flatten(input_shape=(28,28)),
    keras.layers.Dense(128, activation="relu"),
    keras.layers.Dense(10, activation="softmax")
])

# Compile the model
model.compile(optimizer="adam", loss="sparse_categorical_crossentropy", metrics=["accuracy"])

# Custom callback to track unchanged weights
class WeightsTracker(tf.keras.callbacks.Callback):
    def on_train_begin(self, logs=None):
        # Save the initial weights
        self.previous_weights = [layer.get_weights() for layer in self.model.layers if len(layer.get_weights()) > 0]
        self.unchanged_weights = [[np.zeros_like(w) for w in layer_weights] for layer_weights in self.previous_weights]

    def on_epoch_end(self, epoch, logs=None):
        current_weights = [layer.get_weights() for layer in self.model.layers if len(layer.get_weights()) > 0]
        print(f"\nWeights comparison after epoch {epoch + 1}:")

        # Compare current weights with previous weights and track unchanged weights
        for layer_idx, (prev_w, curr_w) in enumerate(zip(self.previous_weights, current_weights)):
            print(f"Layer {layer_idx}:")
            for w_idx, (prev, curr) in enumerate(zip(prev_w, curr_w)):
                unchanged_mask = prev == curr  # Create a mask of unchanged weights
                unchanged_count = np.sum(unchanged_mask)
                total_count = unchanged_mask.size

                # Track unchanged weights for each sub-layer
                self.unchanged_weights[layer_idx][w_idx] = unchanged_mask

                print(f"  Sub-layer {w_idx} - Unchanged Weights: {unchanged_count}/{total_count}")

        # Update previous weights to current for the next epoch comparison
        self.previous_weights = current_weights

    def on_train_end(self, logs=None):
        print("\nFinal unchanged weights mask at the end of training:")
        for layer_idx, weights in enumerate(self.unchanged_weights):
            print(f"Layer {layer_idx}:")
            for w_idx, mask in enumerate(weights):
                unchanged_count = np.sum(mask)
                total_count = mask.size
                print(f"  Sub-layer {w_idx} - Unchanged Weights: {unchanged_count}/{total_count}")

# Instantiate the callback
weights_tracker = WeightsTracker()

# Train the model with the custom callback
model.fit(training_images, training_labels, epochs=10, callbacks=[weights_tracker])

# Evaluate the model
model.evaluate(test_images, test_labels)



#
#
#
#
#
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 [==============================] - 0s 0us/step
# Epoch 1/10
# 1861/1875 [============================>.] - ETA: 0s - loss: 0.2591 - accuracy: 0.9269
# Weights comparison after epoch 1:
# Layer 0:
#   Sub-layer 0 - Unchanged Weights: 11438/100352
#   Sub-layer 1 - Unchanged Weights: 0/128
# Layer 1:
#   Sub-layer 0 - Unchanged Weights: 0/1280
#   Sub-layer 1 - Unchanged Weights: 0/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.2584 - accuracy: 0.9272
# Epoch 2/10
# 1873/1875 [============================>.] - ETA: 0s - loss: 0.1142 - accuracy: 0.9660
# Weights comparison after epoch 2:
# Layer 0:
#   Sub-layer 0 - Unchanged Weights: 13747/100352
#   Sub-layer 1 - Unchanged Weights: 2/128
# Layer 1:
#   Sub-layer 0 - Unchanged Weights: 20/1280
#   Sub-layer 1 - Unchanged Weights: 0/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.1141 - accuracy: 0.9660
# Epoch 3/10
# 1864/1875 [============================>.] - ETA: 0s - loss: 0.0783 - accuracy: 0.9767
# Weights comparison after epoch 3:
# Layer 0:
#   Sub-layer 0 - Unchanged Weights: 13908/100352
#   Sub-layer 1 - Unchanged Weights: 2/128
# Layer 1:
#   Sub-layer 0 - Unchanged Weights: 29/1280
#   Sub-layer 1 - Unchanged Weights: 0/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.0784 - accuracy: 0.9766
# Epoch 4/10
# 1860/1875 [============================>.] - ETA: 0s - loss: 0.0590 - accuracy: 0.9826
# Weights comparison after epoch 4:
# Layer 0:
#   Sub-layer 0 - Unchanged Weights: 14193/100352
#   Sub-layer 1 - Unchanged Weights: 3/128
# Layer 1:
#   Sub-layer 0 - Unchanged Weights: 30/1280
#   Sub-layer 1 - Unchanged Weights: 0/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0589 - accuracy: 0.9827
# Epoch 5/10
# 1865/1875 [============================>.] - ETA: 0s - loss: 0.0458 - accuracy: 0.9858
# Weights comparison after epoch 5:
# Layer 0:
#   Sub-layer 0 - Unchanged Weights: 14263/100352
#   Sub-layer 1 - Unchanged Weights: 3/128
# Layer 1:
#   Sub-layer 0 - Unchanged Weights: 30/1280
#   Sub-layer 1 - Unchanged Weights: 0/10
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.0459 - accuracy: 0.9858
# Epoch 6/10
# 1872/1875 [============================>.] - ETA: 0s - loss: 0.0357 - accuracy: 0.9892
# Weights comparison after epoch 6:
# Layer 0:
#   Sub-layer 0 - Unchanged Weights: 14338/100352
#   Sub-layer 1 - Unchanged Weights: 3/128
# Layer 1:
#   Sub-layer 0 - Unchanged Weights: 30/1280
#   Sub-layer 1 - Unchanged Weights: 0/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0357 - accuracy: 0.9893
# Epoch 7/10
# 1866/1875 [============================>.] - ETA: 0s - loss: 0.0290 - accuracy: 0.9909
# Weights comparison after epoch 7:
# Layer 0:
#   Sub-layer 0 - Unchanged Weights: 14429/100352
#   Sub-layer 1 - Unchanged Weights: 3/128
# Layer 1:
#   Sub-layer 0 - Unchanged Weights: 30/1280
#   Sub-layer 1 - Unchanged Weights: 0/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0291 - accuracy: 0.9908
# Epoch 8/10
# 1871/1875 [============================>.] - ETA: 0s - loss: 0.0242 - accuracy: 0.9922
# Weights comparison after epoch 8:
# Layer 0:
#   Sub-layer 0 - Unchanged Weights: 14529/100352
#   Sub-layer 1 - Unchanged Weights: 3/128
# Layer 1:
#   Sub-layer 0 - Unchanged Weights: 30/1280
#   Sub-layer 1 - Unchanged Weights: 0/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0242 - accuracy: 0.9922
# Epoch 9/10
# 1862/1875 [============================>.] - ETA: 0s - loss: 0.0199 - accuracy: 0.9938
# Weights comparison after epoch 9:
# Layer 0:
#   Sub-layer 0 - Unchanged Weights: 14677/100352
#   Sub-layer 1 - Unchanged Weights: 3/128
# Layer 1:
#   Sub-layer 0 - Unchanged Weights: 30/1280
#   Sub-layer 1 - Unchanged Weights: 0/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0199 - accuracy: 0.9938
# Epoch 10/10
# 1871/1875 [============================>.] - ETA: 0s - loss: 0.0172 - accuracy: 0.9946
# Weights comparison after epoch 10:
# Layer 0:
#   Sub-layer 0 - Unchanged Weights: 14650/100352
#   Sub-layer 1 - Unchanged Weights: 3/128
# Layer 1:
#   Sub-layer 0 - Unchanged Weights: 30/1280
#   Sub-layer 1 - Unchanged Weights: 0/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0173 - accuracy: 0.9945
#
# Final unchanged weights mask at the end of training:
# Layer 0:
#   Sub-layer 0 - Unchanged Weights: 14650/100352
#   Sub-layer 1 - Unchanged Weights: 3/128
# Layer 1:
#   Sub-layer 0 - Unchanged Weights: 30/1280
#   Sub-layer 1 - Unchanged Weights: 0/10
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0909 - accuracy: 0.9779
# [0.09087482839822769, 0.9779000282287598]
